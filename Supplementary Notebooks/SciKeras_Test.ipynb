# %%
import numpy as np
from sklearn.datasets import make_classification
from tensorflow import keras

from scikeras.wrappers import KerasClassifier


X, y = make_classification(1000, 20, n_informative=10, random_state=0)
X = X.astype(np.float32)
y = y.astype(np.int64)

def get_model(hidden_layer_dim, meta):
    # note that meta is a special argument that will be
    # handed a dict containing input metadata
    n_features_in_ = meta["n_features_in_"]
    X_shape_ = meta["X_shape_"]
    n_classes_ = meta["n_classes_"]

    model = keras.models.Sequential()
    model.add(keras.layers.Dense(n_features_in_, input_shape=X_shape_[1:]))
    model.add(keras.layers.Activation("relu"))
    model.add(keras.layers.Dense(hidden_layer_dim))
    model.add(keras.layers.Activation("relu"))
    model.add(keras.layers.Dense(n_classes_))
    model.add(keras.layers.Activation("softmax"))
    return model

clf = KerasClassifier(
    get_model,
    loss="sparse_categorical_crossentropy",
    hidden_layer_dim=100,
)

clf.fit(X, y)
y_proba = clf.predict_proba(X)
# Out:
# 32/32 [==============================] - 2s 4ms/step - loss: 0.6407
# 32/32 [==============================] - 0s 3ms/step

# %%
from sklearn.model_selection import GridSearchCV


params = {
    "hidden_layer_dim": [50, 100, 200],
    "loss": ["sparse_categorical_crossentropy"],
    "optimizer": ["adam", "sgd"],
    "optimizer__learning_rate": [0.0001, 0.001, 0.1],
}
gs = GridSearchCV(clf, params, refit=True, cv=3, scoring='accuracy')

gs.fit(X, y)
print(gs.best_score_, gs.best_params_)
# Out:
# 21/21 [==============================] - 1s 4ms/step - loss: 1.4861
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7653
# 11/11 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 1.1150
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6842
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7462
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6332
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.9303
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.8799
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.8767
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7270
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7984
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.8106
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.8746
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.8726
# 11/11 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7367
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6765
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6997
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6271
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7431
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.8755
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7304
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.8049
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7028
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6998
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.6892
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.7576
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.0894
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7585
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 1.1965
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7881
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7341
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 1.0041
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6831
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.5941
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6817
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6176
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7178
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7009
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.9280
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6524
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6427
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6729
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.2223
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.6528
# 11/11 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 1.3941
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.7902
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7987
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.8482
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6991
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6474
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7192
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6183
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6278
# 11/11 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 1s 4ms/step - loss: 0.6756
# 11/11 [==============================] - 0s 3ms/step
# 32/32 [==============================] - 1s 3ms/step - loss: 1.0098
# 0.7520214825604047 {'hidden_layer_dim': 100, 'loss': 'sparse_categorical_crossentropy', 'optimizer': 'adam', 'optimizer__learning_rate': 0.1}
